# %%
import googlemaps
import pprint
import time

# %%
api_key =

# %%
gmaps = googlemaps.Client(key = api_key)

# %%
places_results = gmaps.places_nearby(location='25.649782,-80.421459', radius = 40000, open_now =False , keyword = 'pilates', type = 'gym')

# %%
pprint.pprint(places_results)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIQEAAFmsYNiJJV7vDeqxqNXfe0KKGHlwjffzDCBNiNhd32G56ahi56JbTw-fPMav2TwYTFLjlAswq93S7XFJxLkQCBHYq3B3Cax1eSlgLBvOtxjM9dwXRJV8uXBn0RU3F17jpJbayhQZJklqho6DSz9RaZCNmExQ6Cx4VNWTxYkz8-U938EOvAM5Z_bbxgEW1iQKa18XyEq4lYIRLdWMjZ6zm_pQpGuJZNJsyHt2w43TIBqlM7frlk86WI1pACioAmFVxGA2D6JUm1f1LiQEICGAydDCLnjxVO4vxJqE1AQa_4xAQ8nAyEQ0Zx85ZZUG1easje4sOuYMYUUTVROc46aLRyV_3dDwt6CtzKKTO4UDsUVaIY7NF1oRD_ro2UjAX--H3pSauGVf5Z2kvzB4v_64qeASEKnWfTkeVkR8deSZkXMzVrcaFPOYF0t2GblArPpgEcytdv_BYCAe',
#  'results': [{'geometry': {'location': {'lat': 25.6708727,
#                                         'lng': -80.38593809999999},
#                            'viewport': {'northeast': {'lat': 25.67222152989272,
#                                                       'lng': -80.38450697010727},
#                                         'southwest': {'lat': 25.66952187010728,
#                                                       'lng': -80.38720662989272}}},
# ...
