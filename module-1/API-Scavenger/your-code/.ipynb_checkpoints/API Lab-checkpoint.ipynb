# %%
import tweepy

API_KEY = 
API_SECRET = 
ACCESS_TOKEN = 
ACCESS_TOKEN_SECRET = 

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
import pandas as pd
def get_followers(user, count=100):
    results = api.followers(user, count=count)
    followers = [pd.Series(follower._json) for follower in results]
    df = pd.DataFrame(followers)
    return df

ironhack = get_followers('PeteButtigieg')
ironhack.head(10)
# Out:
#                     id               id_str              name  \
# 0  1218144307644915712  1218144307644915712        john smith
# 1             30582252             30582252              Kyle
# 2   927918473317150720   927918473317150720       Sarah Riehl
# 3           1591206764           1591206764   Linda Czarnecki
# 4  1225222478768869376  1225222478768869376     Astrea Slezak
# 5  1227992288082583553  1227992288082583553  Latinos For Pete
# 6           3322521362           3322521362       Amber Yates
# 7   723354690151321600   723354690151321600       Marc Hubble
# 8   983463577871937538   983463577871937538          ColleenH
# 9  1227991899941883905  1227991899941883905        Jacqueline
#
#        screen_name                  location  \
# 0  johnsmi01404125
# 1   kylethecrowing            sake lake city
# 2     SarahRiehl14         Pennsylvania, USA
# 3   CzarneckiLinda            Wisconsin, USA
# 4    astrea_slezak
# 5   LatinosForPete  United States of America
# 6    AmberYatesATX
# 7         elbbuh78
# 8  Colleen73346511
# 9  Jacquel52631925
#
#                                          description   url  \
# 0                         Dude who loves hot chicks.  None
# 1                  normal every day nerd, love music  None
# 2  Mom | Wife | Teacher | British Literature and ...  None
# 3           Retired music teacher, current explorer.  None
# 4                     Journalism Student. Marist 21'  None
# 5  Unofficial Latinos For Pete Buttigieg 2020 Twi...  None
# 6                                                     None
# 7                                                     None
# 8                                                     None
# 9                                                     None
#
#                         entities  protected  followers_count  ...  following  \
# 0  {'description': {'urls': []}}       True                1  ...      False
# 1  {'description': {'urls': []}}      False               26  ...      False
# 2  {'description': {'urls': []}}      False               28  ...      False
# 3  {'description': {'urls': []}}      False               50  ...      False
# 4  {'description': {'urls': []}}      False               16  ...      False
# 5  {'description': {'urls': []}}      False                0  ...      False
# 6  {'description': {'urls': []}}      False               14  ...      False
# 7  {'description': {'urls': []}}      False               21  ...      False
# 8  {'description': {'urls': []}}       True                0  ...      False
# 9  {'description': {'urls': []}}      False                0  ...      False
#
#    live_following follow_request_sent  notifications muting blocking  \
# 0           False               False          False  False    False
# 1           False               False          False  False    False
# 2           False               False          False  False    False
# 3           False               False          False  False    False
# 4           False               False          False  False    False
# 5           False               False          False  False    False
# 6           False               False          False  False    False
# 7           False               False          False  False    False
# 8           False               False          False  False    False
# 9           False               False          False  False    False
#
#    blocked_by  translator_type  \
# 0       False             none
# 1       False             none
# 2       False             none
# 3       False             none
# 4       False             none
# 5       False             none
# 6       False             none
# 7       False             none
# 8       False             none
# 9       False             none
#
#                                               status  \
# 0                                                NaN
# 1  {'created_at': 'Tue Feb 11 18:37:09 +0000 2020...
# 2  {'created_at': 'Tue Nov 07 19:49:52 +0000 2017...
# 3  {'created_at': 'Thu Jan 16 17:07:59 +0000 2020...
# 4                                                NaN
# 5                                                NaN
# 6  {'created_at': 'Fri Oct 12 14:55:34 +0000 2018...
# 7                                                NaN
# 8                                                NaN
# 9  {'created_at': 'Thu Feb 13 16:28:25 +0000 2020...
#
#                                   profile_banner_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  https://pbs.twimg.com/profile_banners/12279922...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 47 columns]
