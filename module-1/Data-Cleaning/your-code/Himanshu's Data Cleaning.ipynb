# %%
import numpy as np
import pandas as pd

# %%
#Importing Data as a CSV file into Python 


data = pd.read_csv('C:/Users/denis/Desktop/Ironhack/ironhackLabs/module-1/Data-Cleaning/datacopy.csv')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %%
#Understanding the shape of the data
data.shape

# %%
# Getting an understanding of the columns in the data 
##Need to examine whether these columns are correctly classified, need to change Year to object
data.columns
data.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
#examining missing values 
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Filtering out missing data 
# I decided to only remove Unnamed 22 & 23 due to missing data

drop_cols = list(null_cols[null_cols > 5000].index)
data = data.drop(drop_cols, axis=1)
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN
#
#                                   Injury Fatal (Y/N)   Time   Species   \
# ...

# %%
# Change Year from int to object: 
data['Year'] = data['Year'].astype('object')
data['Year'].dtype
# Out:
# dtype('O')

# %%
# Cleaning Columns
# The names, pdf, href, href formula, additional case numbers and original number columns are redundant or messy, 
#so we will scrap it. 
data = data.drop(["Name","pdf", "href", "href formula","Case Number.1", "Case Number.2", "original order" ], axis=1)
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   M   36
# 2  New Smyrna Beach, Volusia County  Surfing   M   43
# 3                  Thirteenth Beach  Surfing   M  NaN
# 4                       Bells Beach  Surfing   M  NaN
#
#                                   Injury Fatal (Y/N)   Time   Species   \
# 0                  Minor injury to thigh           N  13h00        NaN
# 1                   Lacerations to hands           N  11h00        NaN
# ...

# %%
# Cleaning the Sex column 
#First, there's an extra space in Sex_, so we'll remove that
data = data.rename(columns={"Sex ":"Sex"})
data.columns

# We want to examine the items in the Sex column
data['Sex'].value_counts()

#I want to rename entries "M " and "lli" and remove entries "." and "N"
data.Sex = data.Sex.replace({"M ": "M", "lli": "M"})

data = data[data['Sex']!='.']
data = data[data['Sex']!='N']
#The Sex column has now been cleaned 
data['Sex'].value_counts()
# Out:
# M    4838
# F     585
# Name: Sex, dtype: int64

# %%
# cleaning Age
data['Age'].value_counts()
data["Age"]= data["Age"].astype(str)
# # data["Age new"]= data["Age"].str.replace("A-Za-z", "") 
data["bool_series1"]= data["Age"].str.isdigit()
# data["bool_series2"]= data["Age new"].str.isdigit() 
data.head(10) 


# data[data['Age']].rstrip('s')
# replace needs a specific value to match 
# data["Age"]= data["Age"].replace
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %%
# filtered_sex = data['Sex']=='N'
# data_sex = data[filtered_sex]
# data_sex
# #I want to rename entries "M " and "lli" and remove entries "." and "N"
# data.Sex = data.Sex.replace({"M ": "M", "lli": "M"})

# data['Sex'].value_counts()
# Out:
# M    4838
# F     585
# .       1
# N       1
# Name: Sex, dtype: int64

# %%
# Now I want to check for duplicate entries based on Case Number

# duplicateRowsDF = data[data.duplicated(['Case Number'])]
# print(duplicateRowsDF)

duplicateRowsDF = data[data.duplicated(subset=["Case Number"], keep=False)]
duplicateRowsDF

# %%
# data['Case Number'].value_counts().index

# %%
# data[data.duplicated(subset=['Case Number'])].sort_values(by='Case Number')

# %%
# Select all duplicate rows based on multiple column names in list
# duplicateRowsDF = data[data.duplicated(['Country'+'Area'])]

# %%
# duplicateRowsDF.sort_values(by='Case Number',ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# data.duplicated(['Case Number'])
