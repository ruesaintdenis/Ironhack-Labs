# %%
import random

rannum = random.randint(1,101)

guesses_remaining = 5
print("Welcome to Guess a Number")

keep_playing = True 
while keep_playing:
    print("You have ", guesses_remaining, " guesses remaining.")
    prompt = input('To play, please enter a number between 1-100: ')
    print(prompt)
    try: 
        prompt = int(prompt)
        if prompt>0 and prompt<101: 
                guesses_remaining -= 1
                if prompt == rannum: 
                    print('Congrats, you got it!')
                    keep_playing = False
                else: 
                    if guesses_remaining == 0:
                        print("You have no more guesses allowed. The correct number was " + str(rannum))
                        keep_playing = False 
                    elif prompt > (rannum +20): 
                        print("You are very cold, try a drastically lower number")
                    elif prompt < (rannum-20):
                        print("You are very cold, try a drastically higher number")
                    elif (rannum +20 >= prompt >= rannum +10):
                        print("You are warm. Try a lower number")
                    elif (rannum -10 >= prompt >= rannum -20):
                        print("You are warm. Try a higher number")
                    elif (rannum +10 > prompt >rannum):
                        print("HOT! Try a slight lower number")
                    elif (rannum> prompt > rannum-10): 
                        print("HOT! Try a slightly higher number")
        else:
            print("Please enter a number within 1-100")
    except ValueError: 
        print("Please enter a number within 1-100")
# Out:
# Welcome to Guess a Number
# You have  5  guesses remaining.
# To play, please enter a number between 1-100: 5884349
# 5884349
# Please enter a number within 1-100
# You have  5  guesses remaining.
# To play, please enter a number between 1-100: df
# df
# Please enter a number within 1-100
# You have  5  guesses remaining.

# %%
#         if prompt>0 and prompt<101: 
#                 guesses_remaining -= 1
#                 if prompt == rannum: 
#                     print('Congrats, you got it!')
#                     keep_playing = False
#                 else: 
#                     if guesses_remaining == 0:
#                         print("You have no more guesses allowed. The correct number was " + str(rannum))
#                         keep_playing = False 
#                     elif prompt > (rannum +20) or prompt < (rannum-20):
#                         print("You are very cold")
#                     elif (rannum +20 >= prompt >= rannum +10) or (rannum -10 >= prompt >= rannum -20):
#                         print("You are warm")
#                     elif (rannum +10 > prompt >rannum) or (rannum> prompt > rannum-10): 
#                         print("HOT!")
#                 flag = False
#         else: 
#             print("Please enter a number within 1-100")
# #     guesses_remaining -= 1
#     if prompt == rannum: 
#         print('Congrats, you got it!')
#         keep_playing = False
#     else: 
#         if guesses_remaining == 0:
#             print("You have no more guesses allowed. The correct number was " + str(rannum))
#             keep_playing = False 
#         elif prompt > (rannum +20) or prompt < (rannum-20):
#             print("You are very cold")
#         elif (rannum +20 >= prompt >= rannum +10) or (rannum -10 >= prompt >= rannum -20):
#             print("You are warm")
#         elif (rannum +10 > prompt >rannum) or (rannum> prompt > rannum-10): 
#             print("HOT!")
            

#     break
