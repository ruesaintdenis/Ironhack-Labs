# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

# %%
url = 'https://miami.craigslist.org/'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="https://miami.craigslist.org/" property="og:url"/>
# <link href="https://miami.craigslist.org/" rel="canonical"/>
# <title>craigslist: south florida jobs, apartments, for sale, services, community, and events</title>
# <meta content="craigslist provides local classifieds and forums for jobs, housing, for sale, services, local community, and events" name="description"/>
# <meta content="Ie0Do80edB2EurJYj-bxqMdX7zkMjx_FnjtQp_XMFio" name="google-site-verification"/>
# <meta content="3402AB8563AB1E080501C21306FE7811" name="msvalidate.01"/>
# <meta content="25.773899, -80.193901" name="ICBM"/>
# ...

# %%
# table = soup.find_all('div',{'id':'rightbar'})[0]
table2 = soup.find_all('ul',{'class':'menu collapsible'})[0]
table2
# Out:
# <ul class="menu collapsible"><li class="expand s"><h5 class="ban">nearby cl</h5><ul class="acitem">
# <li class="s"><a href="//albanyga.craigslist.org/">albany</a>
# </li><li class="s"><a href="//augusta.craigslist.org/">augusta</a>
# </li><li class="s"><a href="//brunswick.craigslist.org/">brunswick</a>
# </li><li class="s"><a href="//charleston.craigslist.org/">charleston</a>
# </li><li class="s"><a href="//columbusga.craigslist.org/">columbus</a>
# </li><li class="s"><a href="//daytona.craigslist.org/">daytona beach</a>
# </li><li class="s"><a href="//dothan.craigslist.org/">dothan</a>
# </li><li class="s"><a href="//keys.craigslist.org/">florida keys</a>
# </li><li class="s"><a href="//fortmyers.craigslist.org/">fort myers</a>
# </li><li class="s"><a href="//gainesville.craigslist.org/">gainesville</a>
# </li><li class="s"><a href="//cfl.craigslist.org/">heartland fl</a>
# </li><li class="s"><a href="//hiltonhead.craigslist.org/">hilton head</a>
# ...

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here

url = 'https://github.com/trending/developers'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-6548d5a1dd84bd83036c6a914b25b4ae.css" integrity="sha512-ZUjVod2EvYMDbGqRSyW0rpfgBq3i+gnR/4PfrzLsy5f20oIcRfgFQFVKgi3Ztp917bP1K/kdP5q8+nAlJ3+cFA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# # your code here
# table = soup.find_all('div',{'class':'box'})[0]
# # table2 = soup.find_all('ul',{'class':'menu collapsible'})[0]
# # table2
# table

# %%
names = []
username = []
for item in soup.find_all('h1', {'class':'h3 lh-condensed'}):
#     print(item)
#     print('\n\n\n')
    x = item.text
    x = " ".join(re.findall('[A-z]+', x))
    names.append(x)
    y = item.find('a')['href']
    y = " ".join(re.findall('[A-z]+', y))
    username.append(y)
username
# Out:
# ['gcanti',
#  'dotansimha',
#  'timothycrosley',
#  'compnerd',
#  'hiroppy',
#  'kkaefer',
#  'dagar',
#  'klauspost',
#  'bpasero',
#  'sandersn',
#  'stefanprodan',
#  'edenhill',
#  'sirreal',
#  'rmosolgo',
#  'BurntSushi',
#  'rrousselGit',
#  'nunomaduro',
#  'adriancole',
#  'RichardKnop',
#  'sdispater',
#  'thestr ng r',
#  'nicholasjackson',
#  'buger',
#  'kamilkisiela',
#  'beberlei']

# %%
rc = []
for i, j in zip(names, username):
    rc.append(i)
    rc.append(j)
# print(rc)
N = 2
temp = '{} ' * N  
res = [temp.format(*ele) for ele in zip(*[iter(rc)] * N)]
print(res)
# Out:
# ['Giulio Canti gcanti ', 'Dotan Simha dotansimha ', 'Timothy Edmund Crosley timothycrosley ', 'Saleem Abdulrasool compnerd ', 'Yuta Hiroto hiroppy ', 'Konstantin K fer kkaefer ', 'Daniel Agar dagar ', 'Klaus Post klauspost ', 'Benjamin Pasero bpasero ', 'Nathan Shively Sanders sandersn ', 'Stefan Prodan stefanprodan ', 'Magnus Edenhill edenhill ', 'Jon Surrell sirreal ', 'Robert Mosolgo rmosolgo ', 'Andrew Gallant BurntSushi ', 'Remi Rousselet rrousselGit ', 'Nuno Maduro nunomaduro ', 'Adrian Cole adriancole ', 'Richard Knop RichardKnop ', 'S bastien Eustace sdispater ', 'Florian M rkl thestr ng r ', 'Nicholas Jackson nicholasjackson ', 'Leonid Bugaev buger ', 'Kamil Kisiela kamilkisiela ', 'Benjamin Eberlei beberlei ']

# %%
x = soup.find_all('h1', {'class':'h3 lh-condensed'})[2].text
" ".join(re.findall('[A-z]+', x))
# Out:
# 'Timothy Edmund Crosley'

# %%
y = item.find('a')['href']
" ".join(re.findall('[A-z]+', y))
# Out:
# 'gcanti'

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
url = 'https://github.com/trending/python?since=daily'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# %%
soup.find_all('h1', {'class':'h3 lh-condensed'})[0]('a')[0]['href']
# Out:
# '/microsoft/DeepSpeed'

# %%
repo = []
for item in soup.find_all('h1', {'class':'h3 lh-condensed'}):
#     print(item)
#     print('\n\n\n')
    x = item.find('a')['href']
    repo.append(x)
print(repo)
# Out:
# ['/microsoft/DeepSpeed', '/OpenMined/PySyft', '/pymatting/pymatting', '/google-research/text-to-text-transfer-transformer', '/confluentinc/confluent-kafka-python', '/saltstack/salt', '/python/mypy', '/bregman-arie/devops-exercises', '/deepmind/sonnet', '/edwardz246003/shadowsocks', '/microsoft/c9-python-getting-started', '/seleniumbase/SeleniumBase', '/keras-team/keras', '/huggingface/transformers', '/netbox-community/netbox', '/marblexu/PythonPlantsVsZombies', '/django/django', '/biubug6/Pytorch_Retinaface', '/EdjeElectronics/TensorFlow-Object-Detection-API-Tutorial-Train-Multiple-Objects-Windows-10', '/elimintz/justpy', '/robotframework/robotframework', '/DataDog/integrations-core', '/mingrammer/diagrams', '/d2l-ai/d2l-en', '/apache/incubator-tvm']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

images = soup.find_all('img', {'src':re.compile('.jpg')})
for image in images: 
    print(image['src']+'\n')
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg
#
# //upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg
#
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
url = 'https://en.wikipedia.org/wiki/Pythonidae'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")
links = []

for link in soup.findAll('a', attrs={'href': re.compile("^http://")}):
    links.append(link.get('href'))

print(links)
# Out:
# ['http://news.nationalgeographic.com/news/2004/06/0603_040603_invasivespecies.html', 'http://www.anapsid.org/coloburm.html', 'http://m.humanesociety.org/assets/pdfs/wildlife/captive/constrictor-snake-attacks.pdf', 'http://www.rgrahamreynolds.info/wp-content/uploads/2014/01/Reynolds_etal_2014_MPE.pdf', 'http://www.jpanafrican.org/docs/vol8no9/8.9-10-FDiawuo.pdf', 'http://reptile-database.reptarium.cz/search.php?submit=Search&taxon=Pythonidae', 'http://reptile-database.reptarium.cz/', 'http://www.answers.com/topic/pythons-pythonidae-biological-family', 'http://www.answers.com/', 'http://fossilworks.org/bridge.pl?a=taxonInfo&taxon_no=99994', 'http://www.irmng.org/aphia.php?p=taxdetails&id=118691']

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
url = 'https://www.fbi.gov/wanted/topten'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# %%
soup.find_all('h3',{'class':'title'})[0]('a')[0]['href'].rsplit('/',1)[1]
# Out:
# 'arnoldo-jimenez'

# %%
names = []
for item in soup.find_all('h3',{'class':'title'}):
#     print(item)
#     print('\n\n\n')
    x = item.find('a')['href'].rsplit('/',1)[1]
    names.append(x)
print(names)
# Out:
# ['arnoldo-jimenez', 'yaser-abdel-said', 'jason-derek-brown', 'alexis-flores', 'eugene-palmer', 'santiago-mederos', 'rafael-caro-quintero', 'robert-william-fisher', 'bhadreshkumar-chetanbhai-patel', 'alejandro-castillo']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here
url = 'https://data.gov.uk/'
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# %%
# soup.find_all('div', {'class':'column-one-third'})[0]('a')

lst = [0,1,2]
names = []
for item in soup.find_all('div', {'class':'column-one-third'}):
    for i in lst:
        print(item.find_all('a')[i])
#     print('\n\n\n')
#     x = item.find('a').rsplit('=',1)[1]
#     names.append(x)
# # print(names)
#     print(item.find_all('a')['href'])
# Out:
# <a href="/search?filters%5Btopic%5D=Business+and+economy">Business and economy</a>
# <a href="/search?filters%5Btopic%5D=Crime+and+justice">Crime and justice</a>
# <a href="/search?filters%5Btopic%5D=Defence">Defence</a>
# <a href="/search?filters%5Btopic%5D=Environment">Environment</a>
# <a href="/search?filters%5Btopic%5D=Government">Government</a>
# <a href="/search?filters%5Btopic%5D=Government+spending">Government spending</a>
# <a href="/search?filters%5Btopic%5D=Mapping">Mapping</a>
# <a href="/search?filters%5Btopic%5D=Society">Society</a>
# <a href="/search?filters%5Btopic%5D=Towns+and+cities">Towns and cities</a>

# %%
soup.find_all('div', {'class':'column-one-third'})[2]('a')
# Out:
# [<a href="/search?filters%5Btopic%5D=Mapping">Mapping</a>,
#  <a href="/search?filters%5Btopic%5D=Society">Society</a>,
#  <a href="/search?filters%5Btopic%5D=Towns+and+cities">Towns and cities</a>,
#  <a href="/search?filters%5Btopic%5D=Transport">Transport</a>]

# %%
soup.find_all('div', {'class':'column-one-third'})[0]('a')[0]['href']
# Out:
# '/search?filters%5Btopic%5D=Business+and+economy'

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
