# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def acquire():
    data = pd.read_csv('C:/Users/denis/Desktop/Ironhack/ironhackLabs/airline-dataset-for-analysis/FINALdata1.csv', sep=',')
    return data

# %%
def wrangle(df):

#Make Year and Cancelled into object
    data['Year'] = data['Year'].astype('object')
    data['Cancelled'] = data['Cancelled'].astype('object')

#Filter out Years 1989, 1987
    indexNames = data[data['Year'] == 1989].index
    indexNames = data[data['Year'] == 1987].index
    data = data.drop(indexNames, inplace=True)

#drop NaN from column ActualElapsedTime
    filtered = data.dropna(subset=['ActualElapsedTime'])
#
    filtered['Haul'] = list(map(time, filtered['ActualElapsedTime']))

    return filtered

def time(x):
    if x < 180:
        return 'Short'
    elif x >180 and x < 420:
        return 'Medium'
    else:
        return 'Long'
# Out:
# 2008    3019
# 1988    1227
# 1997     599
# Name: Year, dtype: int64

# %%
def analyze(df):
    grouped = filtered.groupby('Make').agg({'Combined MPG':'mean'}).reset_index()
    results = grouped.sort_values('Combined MPG', ascending=False).head(10)
    return results

# %%
data['Haul'] = data.ActualElapsedTime.apply(lamba x: 'short' if x < 180 elif )

# %%
nom = data.groupby(['Haul'])['Cancelled'].sum()
total = data.groupby('Haul').agg({'Cancelled':'count'})
percents = nom.values/total['Cancelled'].values 
vals = pd.DataFrame(percents)
vals.T
# Out:
#        0         1         2
# 0  0.375  0.329932  0.328843

# %%
import matplotlib.pyplot as plt
plt.barh(vals.T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-52e792463d6b> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.barh(vals.T)
#
# TypeError: barh() missing 1 required positional argument: 'width'

# %%
if __name__ == '__main__':
    data = acquire()

# %%
data.head(10)
# Out:
#      Year  Month  Day of month  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99   1988      1             9          6   1348.0        1331   1458.0
# 100  1988      1            10          7   1334.0        1331   1443.0
# 101  1988      1            11          1   1446.0        1331   1553.0
# 102  1988      1            12          2   1334.0        1331   1438.0
# 103  1988      1            13          3   1341.0        1331   1503.0
# 104  1988      1            14          4   1332.0        1331   1447.0
# 105  1988      1            15          5   1331.0        1331   1434.0
# 106  1988      1            16          6   1327.0        1331   1427.0
# 107  1988      1            17          7   1331.0        1331   1440.0
# 108  1988      1            18          1   1349.0        1331   1519.0
#
#      CRSArrTime UniqueCarrier  flight num TailNum  ActualElapsedTime  \
# 99         1435            PI        1458     NaN               70.0
# 100        1435            PI        1225     NaN               69.0
# 101        1435            PI        5667     NaN               67.0
# 102        1435            PI        3445     NaN               64.0
# 103        1435            PI        2233     NaN               82.0
# 104        1435            PI        4567     NaN               75.0
# 105        1435            PI        8765     NaN               63.0
# 106        1435            PI        3568     NaN               60.0
# 107        1435            PI        1254     NaN               69.0
# 108        1435            PI        5432     NaN               90.0
#
#      CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 99               64      NaN      23.0      17.0    SYR  BWI       273
# 100              64      NaN       8.0       3.0    SYR  BWI       273
# 101              64      NaN      78.0      75.0    SYR  BWI       273
# 102              64      NaN       3.0       3.0    SYR  BWI       273
# 103              64      NaN      28.0      10.0    SYR  BWI       273
# 104              64      NaN      12.0       1.0    SYR  BWI       273
# 105              64      NaN      -1.0       0.0    SYR  BWI       273
# 106              64      NaN      -8.0      -4.0    SYR  BWI       273
# 107              64      NaN       5.0       0.0    SYR  BWI       273
# 108              64      NaN      44.0      18.0    SYR  BWI       273
#
#     Cancelled CancellationCode Diverted  CarrierDelay  WeatherDelay  NASDelay  \
# 99          0                N        N           NaN           NaN       NaN
# 100         0                N        N           NaN           NaN       NaN
# 101         0                N        N           NaN           NaN       NaN
# 102         0                N        N           NaN           NaN       NaN
# 103         0                A        N           NaN           NaN       NaN
# 104         1                A        N           NaN           NaN       NaN
# 105         1                B        N           NaN           NaN       NaN
# 106         1                A        Y           NaN           NaN       NaN
# 107         1                A        Y           NaN           NaN       NaN
# 108         1                C        N           NaN           NaN       NaN
#
#      SecurityDelay   Haul
# 99             NaN  Short
# 100            NaN  Short
# 101            NaN  Short
# 102            NaN  Short
# 103            NaN  Short
# 104            NaN  Short
# 105            NaN  Short
# 106            NaN  Short
# 107            NaN  Short
# 108            NaN  Short
