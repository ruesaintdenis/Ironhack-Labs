# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# def acquire():
#     data = pd.read_csv('C:/Users/denis/Desktop/Ironhack/ironhackLabs/airline-dataset-for-analysis/FINALdata1.csv', sep=',')
#     return data

# %%
data.head()
# Out:
#      Year  Month  Day of month  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99   1988      1             9          6   1348.0        1331   1458.0
# 100  1988      1            10          7   1334.0        1331   1443.0
# 101  1988      1            11          1   1446.0        1331   1553.0
# 102  1988      1            12          2   1334.0        1331   1438.0
# 103  1988      1            13          3   1341.0        1331   1503.0
#
#      CRSArrTime UniqueCarrier  flight num TailNum  ActualElapsedTime  \
# 99         1435            PI        1458     NaN               70.0
# 100        1435            PI        1225     NaN               69.0
# 101        1435            PI        5667     NaN               67.0
# 102        1435            PI        3445     NaN               64.0
# 103        1435            PI        2233     NaN               82.0
#
#      CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# ...

# %%
data.dtypes
# Out:
# Year                  object
# Month                  int64
# Day of month           int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# flight num             int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# Cancelled             object
# CancellationCode      object
# Diverted              object
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# dtype: object

# %%
data['Year'].value_counts()
data = data[data['Year'] != 1989]
data['Year'].value_counts()
# Out:
# 2008    3019
# 1988    1227
# 1997     599
# Name: Year, dtype: int64

# %%
def acquire():
    df = pd.read_csv('C:/Users/denis/Desktop/Ironhack/ironhackLabs/airline-dataset-for-analysis/FINALdata1.csv', sep=',')
    return df

def wrangle(df):

#Make Year and Cancelled into object
    df['Year'] = df['Year'].astype('object')
    df['Cancelled'] = df['Cancelled'].astype('object')
    

#Filter out Years 1989, 1987
    df = df[df['Year'] != 1989]
    df = df[df['Year'] != 1987]

#drop NaN from column ActualElapsedTime
    df = df.dropna(subset=['ActualElapsedTime'])
#
    df['Haul'] = list(map(time, df['ActualElapsedTime']))

    return df

def time(x):
    if x < 180:
        return 'Short'
    elif x >180 and x < 420:
        return 'Medium'
    else:
        return 'Long'

def analyze(df):
    nom = df.groupby(['Haul'])['Cancelled'].sum()
    total = df.groupby('Haul').agg({'Cancelled':'count'})
    percents = nom.values/total['Cancelled'].values 
    results = pd.DataFrame(percents, index=['Short Haul', 'Medium Haul', 'Long Haul'])
    results.columns = ['Percent of Flights Cancelled']
    results = results['Percent of Flights Cancelled'].apply(lambda x: x*100)
    return results

# %%
# def analyze():
#     nom = filtered.groupby(['Haul'])['Cancelled'].sum()
#     total = filtered.groupby('Haul').agg({'Cancelled':'count'})
#     percents = nom.values/total['Cancelled'].values 
#     results = pd.DataFrame(percents)
#     return results

# %%
if __name__ == '__main__':
    data = acquire()
    filtered = wrangle(data)
    results = analyze(filtered)

# %%
results
# Out:
# Short Haul     37.500000
# Medium Haul    32.993197
# Long Haul      32.884292
# Name: Percent of Flights Cancelled, dtype: float64

# %%
# import matplotlib.pyplot as plt
# plt.barh(vals.T)

# %%
# nom = data.groupby(['Haul'])['Cancelled'].sum()
# total = data.groupby('Haul').agg({'Cancelled':'count'})
# percents = nom.values/total['Cancelled'].values 
# vals = pd.DataFrame(percents)
# # vals

# %%
# data.head(10)
