# %%
import pandas as pd
food = pd.read_csv('c:/Users/denis/Desktop/Ironhack/ironhackLabs/nutritional-values-for-common-foods-and-products/nutrition.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# food.head()

# %%
x = ['Wheatgrass', 'cinnamon', 'Blueberries', 'Blueberry','Avocado', 'Broccoli', 'Salmon', 'Sweet Potato', 'Goji', 'Milk', 'Almonds', 'Spirulina', 'Acai', 'Coconut', 'Flax']
df1 = pd.DataFrame()
for i in x:
    i = i.lower()
    for item in food['name']:
        items = list(map(lambda a: a.lower(), item.split()))       
        if i in items:
            temp = food[food['name'].str.contains(item)]
            df1 = pd.concat([df1, temp],axis=0) 
    
df1
# Out:
#       Unnamed: 0                                               name  \
# 481          481                                    Bread, cinnamon
# 1209        1209                           Spices, ground, cinnamon
# 1560        1560                  Danish pastry, enriched, cinnamon
# 1767        1767                   KEEBLER, Cinnamon Crisp, Grahams
# 1848        1848                    KEEBLER, Cinnamon Toast Grahams
# ...          ...                                                ...
# 3801        3801     Nuts, without salt added, oil roasted, almonds
# 3802        3802     Nuts, without salt added, dry roasted, almonds
# 4925        4925  Nuts, smoke flavor, with salt added, oil roast...
# 1112        1112                          Seaweed, dried, spirulina
# 1274        1274                            Seaweed, raw, spirulina
#
#      serving_size  calories total_fat saturated_fat cholesterol      sodium  \
# ...

# %%
x = ['blueberries', 'Blueberry','Avocado', 'avocados','Broccoli', 'Salmon', 'Sweet Potato', 'Goji', 'Milk', 'Almonds', 'Spirulina', 'Acai', 'Coconut', 'Flax']
import json
for i in x:
    temp = df_new.loc[df_new['Food_Name']== i.lower()]
    x = temp.T.to_dict().values()
    x = list(x)
    json_file = json.dumps(x)
    with open(i+'.json', 'w') as outfile:
        outfile.write(json_file)

# %%
x = ['Wheatgrass', 'cinnamon', 'blueberries', 'Blueberry','Avocado', 'avocados','Broccoli', 'Salmon', 'Sweet Potato', 'Goji', 'Milk', 'Almonds', 'Spirulina', 'Acai', 'Coconut', 'Flax']
df1 = pd.DataFrame()
import numpy as np
food['Food_Name'] = np.zeros(food.shape[0])
for i in x:
    i = i.lower()
    for item in food['name']:
        items = list(map(lambda a: a.lower(), re.findall('\w+', item)))       
        if i in items:
            temp = food[food['name'].str.contains(item)]
            temp['Food_Name'] = i
            df1 = pd.concat([df1, temp],axis=0) 
    
df1
# Out:
# C:\Users\denis\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       Unnamed: 0                                               name  \
# 481          481                                    Bread, cinnamon
# 1209        1209                           Spices, ground, cinnamon
# 1267        1267                            Bagels, cinnamon-raisin
# 1560        1560                  Danish pastry, enriched, cinnamon
# 1731        1731                   Bagels, toasted, cinnamon-raisin
# 1767        1767                   KEEBLER, Cinnamon Crisp, Grahams
# 1848        1848                    KEEBLER, Cinnamon Toast Grahams
# ...

# %%
# cols = ['col', list(x)]
# cols

df = df1.reindex(columns=['Unnamed: 0','Food_Name','name','serving_size', 'calories','total_fat','saturated_fat','cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin', 'pantothenic_acid','riboflavin','thiamin', 'vitamin_a', 'vitamin_a_rae', 'carotene_alpha','carotene_beta','cryptoxanthin_beta','lutein_zeaxanthin','lucopene','vitamin_b12','vitamin_b6','vitamin_c','vitamin_d','vitamin_e', 'tocopherol_alpha', 'vitamin_k', 'calcium','copper', 'irom','magnesium','manganese','phosphorous','potassium','selenium','zink','protein','alanine','arginine','aspartic_acid', 'cystine','glutamic_acid','glycine','histidine','hydroxyproline','isoleucine', 'leucine', 'lysine','methionine', 'phenylalanine','proline','serine', 'threonine', 'tryptophan', 'tyrosine', 'valine','carbohydrate','fiber', 'sugars','fructose', 'galactose', 'glucose', 'lactose','maltose', 'sucrose','fat','saturated_fatty_acids','monounsaturated_fatty_acids','polyunsaturated_fatty_acids','fatty_acids_total_trans','alcohol','ash','caffeine','theobromine','water'])

# %%
df_new = df.drop(columns=['water', 'theobromine','alcohol','ash','caffeine','glucose', 'lactose','maltose', 'sucrose', 'fructose', 'galactose','proline','serine', 'threonine', 'tryptophan', 'tyrosine', 'valine', 'isoleucine', 'leucine', 'lysine','methionine', 'phenylalanine', 'aspartic_acid', 'cystine','glutamic_acid','glycine','histidine','hydroxyproline','alanine','arginine','selenium','manganese','phosphorous', 'copper', 'tocopherol_alpha','cryptoxanthin_beta','lutein_zeaxanthin','lucopene', 'pantothenic_acid', 'Unnamed: 0'])

# %%
# df_new

# %%
# # # df_new
# df_new = df_new.rename(columns={"name": "Description"})

# %%
# df_new = df_new.reset_index(drop=True)

# %%
# x = ['Blueberries, unsweetened, frozen']
# import re 
# re.findall('\w+', x[0])

# %%
avocado = df_new.loc[df_new['Food_Name']== 'avocado'].copy()

# %%
df_new = df_new.replace({'Food_Name': 'avocados'}, 'avocado')

# %%
cinnamon
# Out:
#    Food_Name                                        Description serving_size  \
# 0   cinnamon                                    Bread, cinnamon        100 g
# 1   cinnamon                           Spices, ground, cinnamon        100 g
# 2   cinnamon                            Bagels, cinnamon-raisin        100 g
# 3   cinnamon                  Danish pastry, enriched, cinnamon        100 g
# 4   cinnamon                   Bagels, toasted, cinnamon-raisin        100 g
# 5   cinnamon                   KEEBLER, Cinnamon Crisp, Grahams        100 g
# 6   cinnamon                    KEEBLER, Cinnamon Toast Grahams        100 g
# 7   cinnamon           KELLOGG'S, Cinnamon Toast, Waffles, EGGO        100 g
# 8   cinnamon             Toaster pastries, brown-sugar-cinnamon        100 g
# 9   cinnamon              PEPPERIDGE FARM, Cinnamon Swirl Bread        100 g
# 10  cinnamon               Fast foods, miniature cinnamon rolls        100 g
# ...

# %%
x = avocado.T.to_dict().values()
x = list(x)
import json
json_file = json.dumps(x)
with open('avocado.json', 'w') as outfile:
    outfile.write(json_file)
